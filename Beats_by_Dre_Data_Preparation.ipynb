# %% [markdown]
# <a href="https://colab.research.google.com/github/KhanhPhantxwes/Beats_By_Dre_DataAnalysis/blob/main/Beats_by_Dre_Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd

# %%
file_path = '/content/sample_data/Bose.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']["asin"]
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["rating"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews_Bose.csv', index=False)
reviews_df
# Out:
#         review_id  product_id  \
# 0   RQ7MQC8CLH2V3  B0D6WD2QSQ
# 1   RZM2F3FFLUDL0  B0D6WD2QSQ
# 2   RCJQ2ZSGU7RPP  B0D6WD2QSQ
# 3  R2SUSKG5E9AHRZ  B0D6WD2QSQ
# 4  R18YGKO63XJUOR  B0D6WD2QSQ
# 5  R13BUTBE2ZS2NL  B0D6WD2QSQ
#
#                                                title           author  rating  \
# 0                     5.0 out of 5 stars HBD to Me!!          J Elsie       5
# 1            5.0 out of 5 stars Great little speaker  Amazon Customer       5
# 2  5.0 out of 5 stars Pricier than most..but IMO ...        E Jackson       5
# 3         5.0 out of 5 stars Great product from BOSE   Lynne A. Coyle       5
# 4  5.0 out of 5 stars When Two Speakers Became On...    Nishant Singh       5
# 5  5.0 out of 5 stars Completely satisfied with t...         Lancelot       5
#
#                                              content  \
# 0  There really is something different about the ...
# 1  I love this speaker. It's exactly what I neede...
# ...

# %%
len(reviews_df)

# %%
df_1 = pd.read_csv('/content/reviews_Beat.csv')
df_2 = pd.read_csv('/content/reviews_BolaButty.csv')
df_3 = pd.read_csv('/content/reviews_Bose.csv')
df_4 = pd.read_csv('/content/reviews_JBL.csv')
df_5 = pd.read_csv('/content/reviews_Sony.csv')

df_2.head()
# Out:
#         review_id  product_id  \
# 0  R25U53QEQ426V1  B0BRKPVZB4
# 1  R3PZDW99DM4O9R  B0BRKPVZB4
# 2  R3KBFKZM4D5CIW  B0BRKPVZB4
# 3  R1U9YZT1YQ1FCE  B0BRKPVZB4
# 4   RZE51KVV6IIFZ  B0BRKPVZB4
#
#                                                title     author  rating  \
# 0  5.0 out of 5 stars Best portable speaker ever ...        Jim       5
# 1  5.0 out of 5 stars Good quality bluetooth spea...     Deaner       5
# 2           5.0 out of 5 stars Better than expected.     JCR-AZ       5
# 3  4.0 out of 5 stars Second time I bought this s...  robert r.       4
# 4          5.0 out of 5 stars Second one works great  Kaitlyn L       5
#
#                                              content  \
# 0  I must have bought over 10 portable speakers o...
# 1  Glad I spent the $20 on this speaker. It has g...
# 2  Amazing price for this item. Charged it up, tu...
# 3  So I'm not saying this is the best speaker out...
# 4  The first one I got was defective. It was bott...
#
# ...

# %%
merged_df = pd.concat([df_1, df_2, df_3, df_4, df_5], ignore_index=True)
merged_df
# Out:
#          review_id  product_id  \
# 0    RHHZJHS7DWJI4  B0DG62YS4Z
# 1   R1PRORF5KAY3OH  B0DG62YS4Z
# 2   R38YUFQL9GEK4H  B0DG62YS4Z
# 3   R1BLTG0ZXMUYFT  B0DG62YS4Z
# 4    R3NYFO9MYXUM1  B0DG62YS4Z
# 5   R1DRXUZX8R4ZOO  B0DG62YS4Z
# 6   R2JY4XLFUJB1AV  B0DG62YS4Z
# 7    RD0J4E6XCGAXE  B0DG62YS4Z
# 8   R25U53QEQ426V1  B0BRKPVZB4
# 9   R3PZDW99DM4O9R  B0BRKPVZB4
# 10  R3KBFKZM4D5CIW  B0BRKPVZB4
# 11  R1U9YZT1YQ1FCE  B0BRKPVZB4
# 12   RZE51KVV6IIFZ  B0BRKPVZB4
# 13  R235QBNRMXAXVW  B0BRKPVZB4
# 14  R3AIBGYIQZF58B  B0BRKPVZB4
# 15   RQ7MQC8CLH2V3  B0D6WD2QSQ
# 16   RZM2F3FFLUDL0  B0D6WD2QSQ
# 17   RCJQ2ZSGU7RPP  B0D6WD2QSQ
# 18  R2SUSKG5E9AHRZ  B0D6WD2QSQ
# 19  R18YGKO63XJUOR  B0D6WD2QSQ
# 20  R13BUTBE2ZS2NL  B0D6WD2QSQ
# 21  R2PEOZ5104S9QZ  B07QDPXCSH
# 22  R2IK77E0Q7YTWP  B07QDPXCSH
# 23  R2DL8LLDSD2DRX  B07QDPXCSH
# 24  R3QQDNYZFKGMUB  B07QDPXCSH
# 25  R1Z4C1N6YNXMJQ  B07QDPXCSH
# 26  R27JY61Q7BJ7Q1  B07QDPXCSH
# 27  R2SETN1GDFV6SP  B07QDPXCSH
# 28  R2XFQQ4U8AK65I  B07QDPXCSH
# ...

# %%
merged_df.to_csv('merged_data.csv', index=False)

# %%
check_df = pd.read_csv('/content/merged_data.csv')
check_df
# Out:
#          review_id  product_id  \
# 0    RHHZJHS7DWJI4  B0DG62YS4Z
# 1   R1PRORF5KAY3OH  B0DG62YS4Z
# 2   R38YUFQL9GEK4H  B0DG62YS4Z
# 3   R1BLTG0ZXMUYFT  B0DG62YS4Z
# 4    R3NYFO9MYXUM1  B0DG62YS4Z
# 5   R1DRXUZX8R4ZOO  B0DG62YS4Z
# 6   R2JY4XLFUJB1AV  B0DG62YS4Z
# 7    RD0J4E6XCGAXE  B0DG62YS4Z
# 8   R25U53QEQ426V1  B0BRKPVZB4
# 9   R3PZDW99DM4O9R  B0BRKPVZB4
# 10  R3KBFKZM4D5CIW  B0BRKPVZB4
# 11  R1U9YZT1YQ1FCE  B0BRKPVZB4
# 12   RZE51KVV6IIFZ  B0BRKPVZB4
# 13  R235QBNRMXAXVW  B0BRKPVZB4
# 14  R3AIBGYIQZF58B  B0BRKPVZB4
# 15   RQ7MQC8CLH2V3  B0D6WD2QSQ
# 16   RZM2F3FFLUDL0  B0D6WD2QSQ
# 17   RCJQ2ZSGU7RPP  B0D6WD2QSQ
# 18  R2SUSKG5E9AHRZ  B0D6WD2QSQ
# 19  R18YGKO63XJUOR  B0D6WD2QSQ
# 20  R13BUTBE2ZS2NL  B0D6WD2QSQ
# 21  R2PEOZ5104S9QZ  B07QDPXCSH
# 22  R2IK77E0Q7YTWP  B07QDPXCSH
# 23  R2DL8LLDSD2DRX  B07QDPXCSH
# 24  R3QQDNYZFKGMUB  B07QDPXCSH
# 25  R1Z4C1N6YNXMJQ  B07QDPXCSH
# 26  R27JY61Q7BJ7Q1  B07QDPXCSH
# 27  R2SETN1GDFV6SP  B07QDPXCSH
# 28  R2XFQQ4U8AK65I  B07QDPXCSH
# ...

# %%
check_df = check_df.drop('Unnamed: 0', axis=1)
check_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-26-971469264.py in <cell line: 0>()
# ----> 1 check_df = check_df.drop('Unnamed: 0', axis=1)
#       2 check_df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
check_df.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')

# %%
merged_df.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')

# %%
merged_df = pd.concat([merged_df,check_df], ignore_index=True)
merged_df
# Out:
#          review_id  product_id  \
# 0    RHHZJHS7DWJI4  B0DG62YS4Z
# 1   R1PRORF5KAY3OH  B0DG62YS4Z
# 2   R38YUFQL9GEK4H  B0DG62YS4Z
# 3   R1BLTG0ZXMUYFT  B0DG62YS4Z
# 4    R3NYFO9MYXUM1  B0DG62YS4Z
# ..             ...         ...
# 69  R3J16MIFZUWVOO  B0C29CL98P
# 70  R1WN0XRI1NXYB7  B0C29CL98P
# 71  R2C76SMSER02YF  B0C29CL98P
# 72   R14K09XCIA66P  B0C29CL98P
# 73  R3J290TP2AE1ZU  B0C29CL98P
#
#                                                 title           author  \
# 0                     5.0 out of 5 stars Great sound!  Kaiser D. Young
# 1                      5.0 out of 5 stars Recommended     Karla Chavez
# 2                    5.0 out of 5 stars Great quality            Ayden
# 3   5.0 out of 5 stars Best Portable Speaker Out T...       Uncle Bits
# 4   1.0 out of 5 stars Physical not good condition...          Mark E.
# ..                                                ...              ...
# 69  4.0 out of 5 stars Cute color, does what it’s ...    Addie Houston
# ...

# %%
merged_df = merged_df.drop_duplicates()
merged_df
# Out:
#          review_id  product_id  \
# 0    RHHZJHS7DWJI4  B0DG62YS4Z
# 1   R1PRORF5KAY3OH  B0DG62YS4Z
# 2   R38YUFQL9GEK4H  B0DG62YS4Z
# 3   R1BLTG0ZXMUYFT  B0DG62YS4Z
# 4    R3NYFO9MYXUM1  B0DG62YS4Z
# 5   R1DRXUZX8R4ZOO  B0DG62YS4Z
# 6   R2JY4XLFUJB1AV  B0DG62YS4Z
# 7    RD0J4E6XCGAXE  B0DG62YS4Z
# 8   R25U53QEQ426V1  B0BRKPVZB4
# 9   R3PZDW99DM4O9R  B0BRKPVZB4
# 10  R3KBFKZM4D5CIW  B0BRKPVZB4
# 11  R1U9YZT1YQ1FCE  B0BRKPVZB4
# 12   RZE51KVV6IIFZ  B0BRKPVZB4
# 13  R235QBNRMXAXVW  B0BRKPVZB4
# 14  R3AIBGYIQZF58B  B0BRKPVZB4
# 15   RQ7MQC8CLH2V3  B0D6WD2QSQ
# 16   RZM2F3FFLUDL0  B0D6WD2QSQ
# 17   RCJQ2ZSGU7RPP  B0D6WD2QSQ
# 18  R2SUSKG5E9AHRZ  B0D6WD2QSQ
# 19  R18YGKO63XJUOR  B0D6WD2QSQ
# 20  R13BUTBE2ZS2NL  B0D6WD2QSQ
# 21  R2PEOZ5104S9QZ  B07QDPXCSH
# 22  R2IK77E0Q7YTWP  B07QDPXCSH
# 23  R2DL8LLDSD2DRX  B07QDPXCSH
# 24  R3QQDNYZFKGMUB  B07QDPXCSH
# 25  R1Z4C1N6YNXMJQ  B07QDPXCSH
# 26  R27JY61Q7BJ7Q1  B07QDPXCSH
# 27  R2SETN1GDFV6SP  B07QDPXCSH
# 28  R2XFQQ4U8AK65I  B07QDPXCSH
# ...

# %%
merged_df.to_csv('new_reference_data_for_beats.csv', index=False)
